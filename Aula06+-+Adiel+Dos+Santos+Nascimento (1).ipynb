# %%
from IPython.display import Image
from IPython.display import HTML
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as npr
import math

# %%
n = np.linspace(1,10, num=1000)
b = np.linspace(1,0, num=1000)

plt.plot(3-2*a)
plt.plot(-2*b)
plt.xlabel('Eixo X')
plt.ylabel('Eixo y')
plt.show()

# %% [markdown]
# <font size="+1"> Resolução do sistema linear mostrado anteriormente  </font>

# %%
a = np.array([[2,1],[1,-3]])
b = np.array([3,-2])

x = np.linalg.solve(a,b)
print(x)

print(np.allclose(np.dot(a,x),b))
# Out:
# [ 1.  1.]
# True

# %% [markdown]
# <font size="+1"> Infinitas Soluções  </font>

# %%
a = np.array([[2,1],[4,2]])
b = np.array([3,6])


print(np.allclose(np.dot(a,x),b))

plt.plot(a,color='red')
plt.plot(b)
plt.xlabel('Eixo X')
plt.ylabel('Eixo y')
plt.show()
# Out:
# True

# %% [markdown]
# <font size="+1"> Nenhuma Solução  </font>

# %%
a = np.array([[2,1],[4,2]])
b = np.array([3,2])


print(np.allclose(np.dot(a,x),b))

plt.plot(a,color='red')
plt.plot(b)
plt.xlabel('Eixo X')
plt.ylabel('Eixo y')
plt.show()
# Out:
# False

# %% [markdown]
# <font size="+1"> Nenhuma Solução  </font>

# %%
A  = np.matrix([[2, 1], [1, -3]])
print(a)

##Informações da matriz 1
v1  = np.array([1, 1])
u1 = np.matmul(A.data, v1)

##Informações da matriz 2
v2  = np.array([2, -1])
u2 = np.matmul(A.data, v2)

plt.plot(u1,color='red')
plt.plot(v1)
plt.xlabel('Eixo X')
plt.ylabel('Eixo y')
plt.show()


plt.plot(u2,color='red')
plt.plot(v2)
plt.xlabel('Eixo X')
plt.ylabel('Eixo y')
plt.show()
# Out:
# [[2 1]
#  [4 2]]

# %%
A  = np.matrix([[2, 1], [1, -3]])
print(a)
# Out:
# [[2 1]
#  [4 2]]
